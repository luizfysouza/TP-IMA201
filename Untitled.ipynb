# %%
import pandas as pd
import numpy as np
import skimage as ski
import matplotlib.pyplot as plt

# %%
im = ski.io.imread('imgs/moscou.jpg')
plt.imshow(im/255)

# %%
im_lab = ski.color.rgb2lab(im/255)

# %%
fig, ax = plt.subplots(1,3, figsize=(12,12))
ax[0].imshow(im_lab[:,:,0]) 
ax[0].set_title('Lightness')
ax[1].imshow(im_lab[:,:,1])
ax[1].set_title('Green to Red')
ax[2].imshow(im_lab[:,:,2])
ax[2].set_title('Blue to yellow')
plt.show()

# %%
im_lab.shape
# Out:
# (5000, 5000, 3)
